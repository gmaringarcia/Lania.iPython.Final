# %%
# %run ../talktools.py
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Nixie+One' rel='stylesheet' type='text/css'>
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
#
# div.cell { /* set cell width */
#     width: 750px;
# }
#
# div #notebook { /* centre the content */
#     background: #fff; /* white background for content */
#     width: 1000px;
#     margin: auto;
#     padding-left: 0em;
# }
#
# #notebook li { /* More space between bullet points */
# margin-top:0.8em;
# }
#
# /* draw border around running cells */
# div.cell.border-box-sizing.code_cell.running {
#     border: 1px solid #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them*/
# div.cell.code_cell {
#     background-color: rgb(256,256,256);
#     border-radius: 0px;
#     padding: 0.5em;
#     margin-left:1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
#     font-family: 'Alegreya Sans' sans-serif;
#     line-height: 140%;
#     font-size: 125%;
#     font-weight: 400;
#     width:600px;
#     margin-left:auto;
#     margin-right:auto;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1 {
#     font-family: 'Nixie One', serif;
#     font-style:regular;
#     font-weight: 400;
#     font-size: 45pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.5em;
#     margin-top: 0.5em;
#     display: block;
# }
# .text_cell_render h2 {
#     font-family: 'Nixie One', serif;
#     font-weight: 400;
#     font-size: 30pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.1em;
#     margin-top: 0.3em;
#     display: block;
# }
#
# .text_cell_render h3 {
#     font-family: 'Nixie One', serif;
#     margin-top:16px;
# 	font-size: 22pt;
#     font-weight: 600;
#     margin-bottom: 3px;
#     font-style: regular;
#     color: rgb(102,102,0);
# }
#
# .text_cell_render h4 {    /*Use this for captions*/
#     font-family: 'Nixie One', serif;
#     font-size: 14pt;
#     text-align: center;
#     margin-top: 0em;
#     margin-bottom: 2em;
#     font-style: regular;
# }
#
# .text_cell_render h5 {  /*Use this for small titles*/
#     font-family: 'Nixie One', sans-serif;
#     font-weight: 400;
#     font-size: 16pt;
#     color: rgb(163,0,0);
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.8em;
#     display: block;
# }
#
# .text_cell_render h6 { /*use this for copyright note*/
#     font-family: 'PT Mono', sans-serif;
#     font-weight: 300;
#     font-size: 9pt;
#     line-height: 100%;
#     color: grey;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono";
#         font-size: 90%;
# }
#
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"],
#                            equationNumbers: { autoNumber: "AMS", useLabelIds: true}
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %%
import pandas as pd
# %matplotlib inline

# %%
archivo = '../files/VR05_11M.xls'
pd.read_excel(archivo).head()
# Out:
#              Estación:  XALAPAob,        VER  Unnamed: 3  Unnamed: 4  \
# 0         Operada por:  SMN ESIME        NaN         NaN         NaN
# 1            Longitud:  96°54'14"  Longitud:    19°30'43    Altitud:
# 2                  NaN        NaN        NaN         NaN         NaN
# 3                FECHA       DIRS       DIRR  RAPVIENTO2  RAPRAFAGA2
# 4  2014-11-04 22:00:00        177        236         1.9         3.8
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0        NaN        NaN        NaN        NaN        NaN
# 1       1360        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN
# 3       TEMP         HR         PB       PREC    RAD-SOL
# 4       18.6         71      865.6          0        179

# %%
pd.read_excel(archivo, header=4).head()
# Out:
#                 FECHA  DIRS  DIRR  RAPVIENTO2  RAPRAFAGA2  TEMP  HR     PB  \
# 0 2014-11-04 22:00:00   177   236         1.9         3.8  18.6  71  865.6
# 1 2014-11-04 22:10:00   168   221         2.3         4.0  18.4  71  865.7
# 2 2014-11-04 22:20:00   172   225         2.2         4.0  18.1  73  865.6
# 3 2014-11-04 22:30:00   191   243         2.1         3.8  17.7  76  865.6
# 4 2014-11-04 22:40:00   196   268         2.2         4.0  17.4  77  865.7
#
#    PREC  RAD-SOL
# 0     0      179
# 1     0      156
# 2     0      117
# 3     0       86
# 4     0       53

# %%
pd.read_excel(archivo, header=4, index_col='FECHA').head()
# Out:
#                      DIRS  DIRR  RAPVIENTO2  RAPRAFAGA2  TEMP  HR     PB  \
# FECHA
# 2014-11-04 22:00:00   177   236         1.9         3.8  18.6  71  865.6
# 2014-11-04 22:10:00   168   221         2.3         4.0  18.4  71  865.7
# 2014-11-04 22:20:00   172   225         2.2         4.0  18.1  73  865.6
# 2014-11-04 22:30:00   191   243         2.1         3.8  17.7  76  865.6
# 2014-11-04 22:40:00   196   268         2.2         4.0  17.4  77  865.7
#
#                      PREC  RAD-SOL
# FECHA
# 2014-11-04 22:00:00     0      179
# 2014-11-04 22:10:00     0      156
# 2014-11-04 22:20:00     0      117
# 2014-11-04 22:30:00     0       86
# 2014-11-04 22:40:00     0       53

# %%
xalapaOb =pd.read_excel(archivo, header=4, index_col='FECHA', parse_dates=True, encoding='utf-8')
xalapaOb.head()
# Out:
#                      DIRS  DIRR  RAPVIENTO2  RAPRAFAGA2  TEMP  HR     PB  \
# FECHA
# 2014-11-04 22:00:00   177   236         1.9         3.8  18.6  71  865.6
# 2014-11-04 22:10:00   168   221         2.3         4.0  18.4  71  865.7
# 2014-11-04 22:20:00   172   225         2.2         4.0  18.1  73  865.6
# 2014-11-04 22:30:00   191   243         2.1         3.8  17.7  76  865.6
# 2014-11-04 22:40:00   196   268         2.2         4.0  17.4  77  865.7
#
#                      PREC  RAD-SOL
# FECHA
# 2014-11-04 22:00:00     0      179
# 2014-11-04 22:10:00     0      156
# 2014-11-04 22:20:00     0      117
# 2014-11-04 22:30:00     0       86
# 2014-11-04 22:40:00     0       53

# %%
xalapaOb.columns
# Out:
# Index([u'DIRS', u'DIRR', u'RAPVIENTO2', u'RAPRAFAGA2', u'TEMP', u'HR', u'PB', u'PREC', u'RAD-SOL'], dtype='object')

# %%
xalapaOb.columns[0]
# Out:
# u'DIRS'

# %%
xalapaOb.columns[0].strip()
# Out:
# u'DIRS'

# %%
xalapaOb[[u'      DIRS']].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-2560ea050d40> in <module>()
# ----> 1 xalapaOb[[u'      DIRS']].head()
#
# C:\Users\Gio\Anaconda\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1670         if isinstance(key, (Series, np.ndarray, list)):
#    1671             # either boolean or fancy integer index
# -> 1672             return self._getitem_array(key)
#    1673         elif isinstance(key, DataFrame):
#    1674             return self._getitem_frame(key)
#
# C:\Users\Gio\Anaconda\lib\site-packages\pandas\core\frame.pyc in _getitem_array(self, key)
#    1714             return self.take(indexer, axis=0, convert=False)
#    1715         else:
# -> 1716             indexer = self.ix._convert_to_indexer(key, axis=1)
#    1717             return self.take(indexer, axis=1, convert=True)
#    1718
#
# C:\Users\Gio\Anaconda\lib\site-packages\pandas\core\indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter)
#    1083                     if isinstance(obj, tuple) and is_setter:
#    1084                         return {'key': obj}
# -> 1085                     raise KeyError('%s not in index' % objarr[mask])
#    1086
#    1087                 return indexer
#
# KeyError: "[u'      DIRS'] not in index"

# %%
xalapaOb[[u'DIRS']].head()
# Out:
#                      DIRS
# FECHA
# 2014-11-04 22:00:00   177
# 2014-11-04 22:10:00   168
# 2014-11-04 22:20:00   172
# 2014-11-04 22:30:00   191
# 2014-11-04 22:40:00   196

# %%
xalapaOb[[u'      TEMP']].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-7ede23ec888c> in <module>()
# ----> 1 xalapaOb[[u'      TEMP']].head()
#
# C:\Users\Gio\Anaconda\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1670         if isinstance(key, (Series, np.ndarray, list)):
#    1671             # either boolean or fancy integer index
# -> 1672             return self._getitem_array(key)
#    1673         elif isinstance(key, DataFrame):
#    1674             return self._getitem_frame(key)
#
# C:\Users\Gio\Anaconda\lib\site-packages\pandas\core\frame.pyc in _getitem_array(self, key)
#    1714             return self.take(indexer, axis=0, convert=False)
#    1715         else:
# -> 1716             indexer = self.ix._convert_to_indexer(key, axis=1)
#    1717             return self.take(indexer, axis=1, convert=True)
#    1718
#
# C:\Users\Gio\Anaconda\lib\site-packages\pandas\core\indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter)
#    1083                     if isinstance(obj, tuple) and is_setter:
#    1084                         return {'key': obj}
# -> 1085                     raise KeyError('%s not in index' % objarr[mask])
#    1086
#    1087                 return indexer
#
# KeyError: "[u'      TEMP'] not in index"

# %%
xalapaOb[[u'TEMP']].head()
# Out:
#                      TEMP
# FECHA
# 2014-11-04 22:00:00  18.6
# 2014-11-04 22:10:00  18.4
# 2014-11-04 22:20:00  18.1
# 2014-11-04 22:30:00  17.7
# 2014-11-04 22:40:00  17.4

# %%
xalapaOb[['TEMP']]
# Out:
#                      TEMP
# FECHA
# 2014-11-04 22:00:00  18.6
# 2014-11-04 22:10:00  18.4
# 2014-11-04 22:20:00  18.1
# 2014-11-04 22:30:00  17.7
# 2014-11-04 22:40:00  17.4
# 2014-11-04 22:50:00  17.2
# 2014-11-04 23:00:00  17.1
# 2014-11-04 23:10:00  16.9
# 2014-11-04 23:20:00  16.8
# 2014-11-04 23:30:00  16.6
# 2014-11-04 23:40:00  16.3
# 2014-11-04 23:50:00  16.3
# 2014-11-05 00:00:00  16.1
# 2014-11-05 00:10:00  15.9
# 2014-11-05 00:20:00  15.8
# 2014-11-05 00:30:00  15.7
# 2014-11-05 00:40:00  15.7
# 2014-11-05 00:50:00  15.6
# 2014-11-05 01:00:00  15.5
# 2014-11-05 01:10:00  15.5
# 2014-11-05 01:20:00  15.5
# 2014-11-05 01:30:00  15.5
# 2014-11-05 01:40:00  15.5
# 2014-11-05 01:50:00  15.4
# 2014-11-05 02:00:00  15.4
# 2014-11-05 02:10:00  15.2
# 2014-11-05 02:20:00  15.1
# 2014-11-05 02:30:00  15.1
# 2014-11-05 02:40:00  15.2
# 2014-11-05 02:50:00  15.3
# ...                   ...
# 2014-11-05 17:00:00  17.9
# 2014-11-05 17:10:00  19.1
# 2014-11-05 17:20:00  19.2
# 2014-11-05 17:30:00  19.6
# 2014-11-05 17:40:00  20.6
# 2014-11-05 17:50:00  20.6
# 2014-11-05 18:00:00  20.9
# 2014-11-05 18:10:00  20.3
# 2014-11-05 18:20:00  21.1
# 2014-11-05 18:30:00  20.7
# 2014-11-05 18:40:00  21.0
# 2014-11-05 18:50:00  21.4
# 2014-11-05 19:00:00  22.0
# 2014-11-05 19:10:00  22.1
# %%
xalapaOb.median()
# Out:
# DIRS          190.0
# DIRR          282.0
# RAPVIENTO2      1.3
# RAPRAFAGA2      2.8
# TEMP           15.2
# HR             92.0
# PB            867.4
# PREC            0.0
# RADSOL          0.0
# dtype: float64

# %%
xalapaOb.mean()
# Out:
# DIRS          195.328671
# DIRR          267.244755
# RAPVIENTO2      1.355944
# RAPRAFAGA2      2.865035
# TEMP           16.197902
# HR             83.538462
# PB            867.304895
# PREC            0.000000
# RADSOL        167.279720
# dtype: float64

# %%
xalapaOb.median().plot(kind='bar')

# %%
xalapaOb.mean().plot(kind='bar')

# %%
figsize(11.5, 6)
font_size = 20
plt.title('Temperatura en Xalapa (24 horas)',fontsize = font_size)
plt.xlabel('hora',fontsize = font_size)
plt.ylabel(r'Temperatura [$^\circ C$] ',fontsize = font_size)
xalapaOb.TEMP.plot();

# %%
figsize(11.5, 6)
font_size = 20
plt.title( 'Radiacion solar', fontsize=font_size)
plt.xlabel('horac', fontsize = font_size)
plt.ylabel(r'$MJ / day / m^2$',fontsize = font_size)
xalapaOb.RADSOL.plot();

# %%
xalapaOb.index
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2014-11-04 22:00:00, ..., 2014-11-05 21:50:00]
# Length: 144, Freq: None, Timezone: None

# %%
madrugada = xalapaOb['2014-11-04 3:00:00' : '2014-11-05 6:00:00']
madrugada.TEMP.head()
# Out:
# FECHA
# 2014-11-04 22:00:00    18.6
# 2014-11-04 22:10:00    18.4
# 2014-11-04 22:20:00    18.1
# 2014-11-04 22:30:00    17.7
# 2014-11-04 22:40:00    17.4
# Name: TEMP, dtype: float64

# %%
media = xalapaOb.TEMP.mean()
media
# Out:
# 16.197902097902098

# %%
madrugada[madrugada.TEMP <= media].head()
# Out:
#                      DIRS  DIRR  RAPVIENTO2  RAPRAFAGA2  TEMP  HR     PB  \
# FECHA
# 2014-11-05 00:00:00   170   252         1.6         3.7  16.1  86  866.1
# 2014-11-05 00:10:00   179   233         1.8         3.7  15.9  87  866.2
# 2014-11-05 00:20:00   188   247         1.6         3.4  15.8  88  866.3
# 2014-11-05 00:30:00   183   228         1.7         3.6  15.7  88  866.4
# 2014-11-05 00:40:00   167   226         1.7         3.1  15.7  90  866.6
#
#                      PREC  RADSOL
# FECHA
# 2014-11-05 00:00:00     0       0
# 2014-11-05 00:10:00     0      -1
# 2014-11-05 00:20:00     0      -1
# 2014-11-05 00:30:00     0      -1
# 2014-11-05 00:40:00     0      -1

# %%
madrugada[madrugada.TEMP > media].head()
# Out:
#                      DIRS  DIRR  RAPVIENTO2  RAPRAFAGA2  TEMP  HR     PB  \
# FECHA
# 2014-11-04 22:00:00   177   236         1.9         3.8  18.6  71  865.6
# 2014-11-04 22:10:00   168   221         2.3         4.0  18.4  71  865.7
# 2014-11-04 22:20:00   172   225         2.2         4.0  18.1  73  865.6
# 2014-11-04 22:30:00   191   243         2.1         3.8  17.7  76  865.6
# 2014-11-04 22:40:00   196   268         2.2         4.0  17.4  77  865.7
#
#                      PREC  RADSOL
# FECHA
# 2014-11-04 22:00:00     0     179
# 2014-11-04 22:10:00     0     156
# 2014-11-04 22:20:00     0     117
# 2014-11-04 22:30:00     0      86
# 2014-11-04 22:40:00     0      53

# %%
xalapaOb['TEMP'].describe()
# Out:
# count    143.000000
# mean      16.197902
# std        3.021390
# min       12.600000
# 25%       13.950000
# 50%       15.200000
# 75%       17.850000
# max       23.100000
# dtype: float64

# %%
figsize(11.5, 6)
font_size = 20
plt.title('Distribucion de la rapidez del viento', fontsize=font_size)
# plt.ylabel('frecuen',fontsize = font_size)
plt.xlabel('Nudos',fontsize = font_size)
xalapaOb.RAPVIENTO2.hist(bins=6);
